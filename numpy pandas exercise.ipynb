# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
df = sns.load_dataset("car_crashes")
df.columns
# Out:
# Index(['total', 'speeding', 'alcohol', 'not_distracted', 'no_previous',
#        'ins_premium', 'ins_losses', 'abbrev'],
#       dtype='object')

# %%
list1 = ["NUM_" + col.upper() if df[col].dtype != "O" else col.upper() for col in df.columns]

# %%
list1
# Out:
# ['NUM_TOTAL',
#  'NUM_SPEEDING',
#  'NUM_ALCOHOL',
#  'NUM_NOT_DISTRACTED',
#  'NUM_NO_PREVIOUS',
#  'NUM_INS_PREMIUM',
#  'NUM_INS_LOSSES',
#  'ABBREV']

# %%
list2 = [col.upper() + "_FLAG" if "no" not in col else col.upper() for col in df.columns]

# %%
list2
# Out:
# ['TOTAL_FLAG',
#  'SPEEDING_FLAG',
#  'ALCOHOL_FLAG',
#  'NOT_DISTRACTED',
#  'NO_PREVIOUS',
#  'INS_PREMIUM_FLAG',
#  'INS_LOSSES_FLAG',
#  'ABBREV_FLAG']

# %%
og_list = ["abbrev", "no_previous"]

new_cols = [col for col in df.columns if col not in og_list]

new_df = df[new_cols]

new_df.head()
# Out:
#    total  speeding  alcohol  not_distracted  ins_premium  ins_losses
# 0   18.8     7.332    5.640          18.048       784.55      145.08
# 1   18.1     7.421    4.525          16.290      1053.48      133.93
# 2   18.6     6.510    5.208          15.624       899.47      110.35
# 3   22.4     4.032    5.824          21.056       827.34      142.39
# 4   12.0     4.200    3.360          10.920       878.41      165.63

# %%
df2 = sns.load_dataset("titanic")
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df2["sex"].value_counts()
# Out:
# male      577
# female    314
# Name: sex, dtype: int64

# %%
df2.nunique()
# Out:
# survived         2
# pclass           3
# sex              2
# age             88
# sibsp            7
# parch            7
# fare           248
# embarked         3
# class            3
# who              3
# adult_male       2
# deck             7
# embark_town      3
# alive            2
# alone            2
# dtype: int64

# %%
df2["pclass"].nunique()
# Out:
# 3

# %%
df2[["pclass","parch"]].nunique()
# Out:
# pclass    3
# parch     7
# dtype: int64

# %%
df2["embarked"].dtype
df2["embarked"] = df2["embarked"].astype("category")
df2["embarked"].dtype
# Out:
# CategoricalDtype(categories=['C', 'Q', 'S'], ordered=False)

# %%
df2[df2["embarked"] == "C"].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 19         1       3  female   NaN      0      0   7.2250        C   Third
# 26         0       3    male   NaN      0      0   7.2250        C   Third
# 30         0       1    male  40.0      0      0  27.7208        C   First
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 9   child       False  NaN   Cherbourg   yes  False
# 19  woman       False  NaN   Cherbourg   yes   True
# 26    man        True  NaN   Cherbourg    no   True
# 30    man        True  NaN   Cherbourg    no   True

# %%
df2[df2["embarked"] != "S"].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1          1       1  female  38.0      1      0  71.2833        C   First
# 5          0       3    male   NaN      0      0   8.4583        Q   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 16         0       3    male   2.0      4      1  29.1250        Q   Third
# 19         1       3  female   NaN      0      0   7.2250        C   Third
#
#       who  adult_male deck embark_town alive  alone
# 1   woman       False    C   Cherbourg   yes  False
# 5     man        True  NaN  Queenstown    no   True
# 9   child       False  NaN   Cherbourg   yes  False
# 16  child       False  NaN  Queenstown    no  False
# 19  woman       False  NaN   Cherbourg   yes   True

# %%
df2[(df2["sex"] == "female") & (df2["age"] < 30)].head()
# Out:
#     survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 2          1       3  female  26.0      0      0   7.9250        S   Third
# 8          1       3  female  27.0      0      2  11.1333        S   Third
# 9          1       2  female  14.0      1      0  30.0708        C  Second
# 10         1       3  female   4.0      1      1  16.7000        S   Third
# 14         0       3  female  14.0      0      0   7.8542        S   Third
#
#       who  adult_male deck  embark_town alive  alone
# 2   woman       False  NaN  Southampton   yes   True
# 8   woman       False  NaN  Southampton   yes  False
# 9   child       False  NaN    Cherbourg   yes  False
# 10  child       False    G  Southampton   yes  False
# 14  child       False  NaN  Southampton    no   True

# %%
df2[(df2["fare"] < 500) & (df2["age"] > 70)]
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked  class  who  \
# 96          0       1  male  71.0      0      0  34.6542        C  First  man
# 116         0       3  male  70.5      0      0   7.7500        Q  Third  man
# 493         0       1  male  71.0      0      0  49.5042        C  First  man
# 630         1       1  male  80.0      0      0  30.0000        S  First  man
# 851         0       3  male  74.0      0      0   7.7750        S  Third  man
#
#      adult_male deck  embark_town alive  alone
# 96         True    A    Cherbourg    no   True
# 116        True  NaN   Queenstown    no   True
# 493        True  NaN    Cherbourg    no   True
# 630        True    A  Southampton   yes   True
# 851        True  NaN  Southampton    no   True

# %%
df2.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
df2["deck"].fillna(df2["deck"].mode()[0], inplace = True)
df2["deck"].isnull().sum()
# Out:
# 0

# %%
df2["age"].fillna(df2["age"].median(), inplace = True)

# %%
df2.groupby(["pclass","sex"]).agg({"survived": ["sum","count","mean"]})
# Out:
#               survived
#                    sum count      mean
# pclass sex
# 1      female       91    94  0.968085
#        male         45   122  0.368852
# 2      female       70    76  0.921053
#        male         17   108  0.157407
# 3      female       72   144  0.500000
#        male         47   347  0.135447

# %%
df2["age_flag"] = df2["age"].apply(lambda x: 1 if x < 30 else 0)

# %%
df2.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  age_flag
# 0    man        True  NaN  Southampton    no  False         1
# 1  woman       False    C    Cherbourg   yes  False         0
# 2  woman       False  NaN  Southampton   yes   True         1
# 3  woman       False    C  Southampton   yes  False         0
# 4    man        True  NaN  Southampton    no   True         0

# %%
df3 = sns.load_dataset("tips")

# %%
df3.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df3.groupby("time").agg({"total_bill": ["min", "max", "mean"]})
# Out:
#        total_bill
#               min    max       mean
# time
# Lunch        7.51  43.11  17.168676
# Dinner       3.07  50.81  20.797159

# %%
df3.groupby(["day","time"]).agg({"total_bill": ["min", "max", "mean"]})
# Out:
#             total_bill
#                    min    max       mean
# day  time
# Thur Lunch        7.51  43.11  17.664754
#      Dinner      18.78  18.78  18.780000
# Fri  Lunch        8.58  16.27  12.845714
#      Dinner       5.75  40.17  19.663333
# Sat  Lunch         NaN    NaN        NaN
#      Dinner       3.07  50.81  20.441379
# Sun  Lunch         NaN    NaN        NaN
#      Dinner       7.25  48.17  21.410000

# %%
df3[(df3["time"] == "Lunch") & (df3["sex"] == "Female")].groupby("day").agg({"total_bill": ["sum","min","max","mean"],
                                                                           "tip":  ["sum","min","max","mean"]})
# Out:
#      total_bill                            tip
#             sum    min    max      mean    sum   min   max      mean
# day
# Thur     516.11   8.35  43.11  16.64871  79.42  1.25  5.17  2.561935
# Fri       55.76  10.09  16.27  13.94000  10.98  2.00  3.48  2.745000
# Sat        0.00    NaN    NaN       NaN   0.00   NaN   NaN       NaN
# Sun        0.00    NaN    NaN       NaN   0.00   NaN   NaN       NaN

# %%
df3.loc[(df3["size"] < 3) & (df3["total_bill"] >10 ) , "total_bill"].mean()
# Out:
# 17.184965034965035

# %%
df3["total_bill_tip_sum"] = df3["total_bill"] + df3["tip"]

# %%
df3["total_bill_tip_sum"].sort_values(ascending = False)
# Out:
# 170    60.81
# 212    57.33
# 59     55.00
# 156    53.17
# 182    48.85
#        ...
# 218     9.18
# 195     9.00
# 111     8.25
# 92      6.75
# 67      4.07
# Name: total_bill_tip_sum, Length: 244, dtype: float64

# %%
df4 = df3["total_bill_tip_sum"].sort_values(ascending = False)[:30]

# %%
df4
# Out:
# 170    60.81
# 212    57.33
# 59     55.00
# 156    53.17
# 182    48.85
# 197    48.11
# 23     47.00
# 102    46.80
# 142    46.19
# 95     44.90
# 184    43.55
# 112    42.07
# 207    41.73
# 56     41.01
# 141    41.00
# 238    40.50
# 11     40.26
# 52     40.01
# 85     40.00
# 47     38.40
# 180    38.33
# 179    38.18
# 83     37.68
# 39     36.27
# 167    36.21
# 175    36.01
# 44     36.00
# 173    35.03
# 116    35.00
# 155    34.99
# Name: total_bill_tip_sum, dtype: float64
